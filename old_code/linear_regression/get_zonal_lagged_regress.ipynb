# %%
import matplotlib.gridspec as gridspec

# %%
# %run ./general_functions/get_lagged_regress.ipynb

# %%
# Now, calculate the lagged regressions
# net_cre_zonal_lr = lagged_regress(nino34_rolling,net_cre_anom_zonal,lag).transpose()
# loCld_cre_zonal_lr = lagged_regress(nino34_rolling,loCld_cre_anom_zonal,lag).transpose()
# highCld_cre_zonal_lr = lagged_regress(nino34_rolling,highCld_cre_anom_zonal,lag).transpose()
# clr_sky_zonal_lr = lagged_regress(nino34_rolling,clr_sky_anom_zonal,lag).transpose()
# all_sky_zonal_lr = lagged_regress(nino34_rolling,all_sky_anom_zonal,lag).transpose()

# SST_CRE_zonal_lr = lagged_regress(nino34_rolling,SST_CRE_zonal,lag).transpose()
# EIS_CRE_zonal_lr = lagged_regress(nino34_rolling,EIS_CRE_zonal,lag).transpose()
# Tadv_CRE_zonal_lr = lagged_regress(nino34_rolling,Tadv_CRE_zonal,lag).transpose()

# SST_zonal_lr = lagged_regress(nino34_rolling,SST_anom_zonal,lag).transpose()
# EIS_zonal_lr = lagged_regress(nino34_rolling,EIS_anom_zonal,lag).transpose()
# Tadv_zonal_lr = lagged_regress(nino34_rolling,Tadv_anom_zonal,lag).transpose()

# dR_anom_by_dT_zonal_lr = lagged_regress(nino34_rolling,dR_anom_by_dT_zonal,lag).transpose()
# dR_anom_by_dq_lw_zonal_lr = lagged_regress(nino34_rolling,dR_anom_by_dq_lw_zonal,lag).transpose()
# dR_anom_by_dq_sw_zonal_lr = lagged_regress(nino34_rolling,dR_anom_by_dq_sw_zonal,lag).transpose()

# %%
def get_zonal_lr_plot():
    ### ALL SKY PLOTS ###
    fig, ax = plt.subplots(1, 3, figsize=(18,6),dpi=200)
    fig.tight_layout(w_pad=4,h_pad=10)

    vmin = -1
    vmax = 1

    title1 = ['All Sky','Clear Sky','Net CRE']

    # Plot Trends
    cbar_data = all_sky_lag_zonal.transpose().plot(ax=ax[0],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    clr_sky_lag_zonal.transpose().plot(ax=ax[1],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    net_cre_lag_zonal.transpose().plot(ax=ax[2],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    
    # Give plots their titles
    for i in np.arange(0,3,1):
        ax[i].set_title('Zonal ' + title1[i] + ' regressed onto NINO3.4', fontsize=17)
        ax[i].set_xlabel('Lag (months)', fontsize=17)
        ax[i].tick_params(labelsize=15)
        if i == 0:
            ax[i].set_ylabel('Latitude', fontsize=17)
        else:
            ax[i].set_ylabel('').set_visible(False)

    cbar_ax = fig.add_axes([1.02, 0, 0.01, 1.01])
    cbar = fig.colorbar(cbar_data, cax=cbar_ax, orientation='vertical', extend='both')
    cbar.ax.tick_params(labelsize=20)
    cbar.set_label(label='$W/m^2/K$', size=20)
    
    ### NET CRE PLOTS ###
    fig, ax = plt.subplots(1, 3, figsize=(18,6))
    fig.tight_layout(w_pad=4,h_pad=10)

    vmin = -1
    vmax = 1
    
    title2 = ['Net CRE','Low Cloud CRE','High Cloud CRE']
    
    cbar_data = net_cre_lag_zonal.transpose().plot(ax=ax[0],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    loCld_cre_lag_zonal.transpose().plot(ax=ax[1],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    highCld_cre_lag_zonal.transpose().plot(ax=ax[2],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)

    # Give plots their titles
    for i in np.arange(0,3,1):
        ax[i].set_title('Zonal ' + title2[i] + ' regressed onto NINO3.4', fontsize=17)
        ax[i].set_xlabel('Lag (months)', fontsize=17)
        ax[i].tick_params(labelsize=15)
        if i == 0:
            ax[i].set_ylabel('Latitude', fontsize=17)
        else:
            ax[i].set_ylabel('').set_visible(False)

    cbar_ax = fig.add_axes([1.02, 0, 0.01, 1.01])
    cbar = fig.colorbar(cbar_data, cax=cbar_ax, orientation='vertical', extend='both')
    cbar.ax.tick_params(labelsize=20)
    cbar.set_label(label='$W/m^2/K$', size=20)
    
    ### LOW CLD CRE PLOTS ###
    fig, ax = plt.subplots(1, 4, figsize=(26,8))
    fig.tight_layout(w_pad=4,h_pad=10)

    vmin = -1
    vmax = 1
    
    title3 = ['Low Cloud CRE','CRE by SST','CRE by EIS','CRE by Tadv']
    
    cbar_data = loCld_cre_lag_zonal.transpose().plot(ax=ax[0],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    SST_CRE_zonal.transpose().plot(ax=ax[1],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    EIS_CRE_zonal.transpose().plot(ax=ax[2],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    Tadv_CRE_zonal.transpose().plot(ax=ax[3],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)

    # Give plots their titles
    for i in np.arange(0,4,1):
        ax[i].set_title('Zonal ' + title3[i] + ' regressed onto NINO3.4', fontsize=17)
        ax[i].set_xlabel('Lag (months)', fontsize=17)
        ax[i].tick_params(labelsize=15)
        if i == 0:
            ax[i].set_ylabel('Latitude', fontsize=17)
        else:
            ax[i].set_ylabel('').set_visible(False)

    cbar_ax = fig.add_axes([1.02, 0, 0.01, 1.01])
    cbar = fig.colorbar(cbar_data, cax=cbar_ax, orientation='vertical', extend='both')
    cbar.ax.tick_params(labelsize=20)
    cbar.set_label(label='$W/m^2/K$', size=20)
    
    ### CLR SKY PLOTS ###
    fig, ax = plt.subplots(1, 4, figsize=(26,8))
    fig.tight_layout(w_pad=4,h_pad=10)

    vmin = -1
    vmax = 1
    
    title4 = ['Clear Sky','$dR/dT$','$dR/dq_{LW}$','$dR/dq_{SW}$']
    
    cbar_data = clr_sky_lag_zonal.transpose().plot(ax=ax[0],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    dR_dT_zonal.transpose().plot(ax=ax[1],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    dR_dq_lw_zonal.transpose().plot(ax=ax[2],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)
    dR_dq_sw_zonal.transpose().plot(ax=ax[3],cmap=plt.get_cmap('RdBu').reversed(),
                           add_colorbar=False,vmin=vmin,vmax=vmax)

    # Give plots their titles
    for i in np.arange(0,4,1):
        ax[i].set_title('Zonal ' + title4[i] + ' regressed onto NINO3.4', fontsize=17)
        ax[i].set_xlabel('Lag (months)', fontsize=17)
        ax[i].tick_params(labelsize=15)
        if i == 0:
            ax[i].set_ylabel('Latitude', fontsize=17)
        else:
            ax[i].set_ylabel('').set_visible(False)

    cbar_ax = fig.add_axes([1.02, 0, 0.01, 1.01])
    cbar = fig.colorbar(cbar_data, cax=cbar_ax, orientation='vertical', extend='both')
    cbar.ax.tick_params(labelsize=20)
    cbar.set_label(label='$W/m^2/K$', size=20)
    
#     path = '/data/keeling/a/tjhanke2/enso-energy-budget/Output/Plots/linear_regression/'
#     fig.savefig(path + 'zonal_mean_lagged_regress.png', bbox_inches='tight')

    ### CCF PLOTS ###
    fig, ax = plt.subplots(2, 3, figsize=(18,18))
    fig.tight_layout(w_pad=5,h_pad=2)

    vmin = -0.3
    vmax = 0.3

    lin_title = [['CRE by SST','CRE by EIS','CRE by Tadv'],
                ['SST','EIS','Tadv']]

    # Plot Trends
    SST_CRE_zonal.transpose().plot(ax=ax[0,0],cmap=plt.get_cmap('RdBu').reversed(),
                           cbar_kwargs={'shrink': 0.9,'label': '$W/m^2/K$','orientation': 'horizontal'},vmin=vmin,vmax=vmax)
    EIS_CRE_zonal.transpose().plot(ax=ax[0,1],cmap=plt.get_cmap('RdBu').reversed(),
                           cbar_kwargs={'shrink': 0.9,'label': '$W/m^2/K$','orientation': 'horizontal'},vmin=vmin,vmax=vmax)
    Tadv_CRE_zonal.transpose().plot(ax=ax[0,2],cmap=plt.get_cmap('RdBu').reversed(),
                           cbar_kwargs={'shrink': 0.9,'label': '$W/m^2/K$','orientation': 'horizontal'},vmin=vmin,vmax=vmax)
    SST_anom_zonal.transpose().plot(ax=ax[1,0],cmap=plt.get_cmap('RdBu').reversed(),
                           cbar_kwargs={'shrink': 0.9,'label': '$K/K$','orientation': 'horizontal'},vmin=vmin,vmax=vmax)
    EIS_anom_zonal.transpose().plot(ax=ax[1,1],cmap=plt.get_cmap('RdBu').reversed(),
                           cbar_kwargs={'shrink': 0.9,'label': '$K/K$','orientation': 'horizontal'},vmin=vmin,vmax=vmax)
    Tadv_anom_zonal.transpose().plot(ax=ax[1,2],cmap=plt.get_cmap('RdBu').reversed(),
                           cbar_kwargs={'shrink': 0.9,'label': '$K/day/K$','orientation': 'horizontal'},vmin=vmin,vmax=vmax)


    # Give plots their titles
    for i in np.arange(0,2,1):
        for j in np.arange(0,3,1):
            ax[i,j].set_title('Zonal ' + lin_title[i][j] + ' regressed onto NINO3.4', fontsize=17)
            ax[i,j].set_xlabel('Lag (months)', fontsize=17)
            if j == 0:
                ax[i,j].set_ylabel('Latitude', fontsize=17)
            else:
                ax[i,j].set_ylabel('').set_visible(False)
            ax[i,j].tick_params(labelsize=20)
