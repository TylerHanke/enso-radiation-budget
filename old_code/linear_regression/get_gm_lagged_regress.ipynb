# %%
# %run ./general_functions/get_lagged_regress.ipynb

# %%
# Now, calculate the lagged regressions
# net_cre_gm, net_cre_err = lagged_regress(nino34_rolling,net_cre_anom_gm,lag)
# loCld_cre_gm, loCld_cre_err = lagged_regress(nino34_rolling,loCld_cre_anom_gm,lag)
# highCld_cre_gm, highCld_cre_err = lagged_regress(nino34_rolling,highCld_cre_anom_gm,lag)
# clr_sky_gm, clr_sky_err = lagged_regress(nino34_rolling,clr_sky_anom_gm,lag)
# all_sky_gm, all_sky_err = lagged_regress(nino34_rolling,all_sky_anom_gm,lag)
# tot_cre_gm = net_cre_gm+clr_sky_gm

# dR_by_dT_gm, dR_by_dT_err = lagged_regress(nino34_rolling,dR_anom_by_dT_gm,lag)
# dR_by_dq_sw_gm, dR_by_dq_sw_err = lagged_regress(nino34_rolling,dR_anom_by_dq_sw_gm,lag)
# dR_by_dq_lw_gm, dR_by_dq_lw_err = lagged_regress(nino34_rolling,dR_anom_by_dq_lw_gm,lag)

# SST_CRE_lr_gm, SST_CRE_lr_err = lagged_regress(nino34_rolling,SST_CRE_gm,lag)
# EIS_CRE_lr_gm, EIS_CRE_lr_err = lagged_regress(nino34_rolling,EIS_CRE_gm,lag)
# Tadv_CRE_lr_gm, Tadv_CRE_lr_err = lagged_regress(nino34_rolling,Tadv_CRE_gm,lag)

# SST_gm, SST_err = lagged_regress(nino34_rolling,SST_anom_gm,lag)
# EIS_gm, EIS_err = lagged_regress(nino34_rolling,EIS_anom_gm,lag)
# Tadv_gm, Tadv_err = lagged_regress(nino34_rolling,Tadv_anom_gm,lag)

# %%
def get_gm_lr_plot():
    # Set up subplots figure with PlateCarree projection
    fig, ax = plt.subplots(2, 2, figsize=(18,12),dpi=200)
    fig.tight_layout(w_pad=6,h_pad=6)
    
    lin_title = [['ALL-SKY','NET CRE'],
                 ['LOW CLOUD CRE','CLEAR-SKY']]

    # Plot Trends
    ax[0,0].plot(lag,all_sky_lag_gm,'black',label='ALL SKY')
    ax[0,0].plot(lag,clr_sky_lag_gm,'green',label='CLR SKY')
    ax[0,0].plot(lag,net_cre_lag_gm,'purple',label='NET CRE')
    ax[0,0].plot(lag,loCld_cre_lag_gm,'red',label='LOW CLD (> 680 hPa) CRE',linestyle='dashed')
    ax[0,0].plot(lag,highCld_cre_lag_gm,'blue',label='HIGH CLD (< 680 hPa) CRE',linestyle='dashdot')
     
    ax[0,1].plot(lag,net_cre_lag_gm,'purple',label='NET CRE')
  #  ax[0,1].fill_between(lag,net_cre_err[:,0],net_cre_err[:,1],color='purple',linestyle='dashed',alpha=0.05)    
    ax[0,1].plot(lag,loCld_cre_lag_gm,'red',label='LOW CLD (> 680 hPa) CRE',linestyle='dashed')
  #  ax[0,1].fill_between(lag,loCld_cre_err[:,0],loCld_cre_err[:,1],color='red',linestyle='dashed',alpha=0.05)
    ax[0,1].plot(lag,highCld_cre_lag_gm,'blue',label='HIGH CLD (< 680 hPa) CRE',linestyle='dashdot')
  #  ax[0,1].fill_between(lag,highCld_cre_err[:,0],highCld_cre_err[:,1],color='blue',linestyle='dashed',alpha=0.05)

    ax[1,0].plot(lag,loCld_cre_lag_gm,'red',label='LOW CLD (> 680 hPa) CRE')
#    ax[1,0].fill_between(lag,loCld_cre_err[:,0],loCld_cre_err[:,1],color='red',linestyle='dashed',alpha=0.05)
#    ax[1,0].plot(lag,SST_CRE_lr_lag_gm,'teal',label='CRE by SST',linestyle='dashed')
#    ax[1,0].fill_between(lag,SST_CRE_lr_err[:,0],SST_CRE_lr_err[:,1],color='teal',linestyle='dashed',alpha=0.05)
#    ax[1,0].plot(lag,EIS_CRE_lr_lag_gm,'darkblue',label='CRE by EIS',linestyle='dashdot')
#    ax[1,0].fill_between(lag,EIS_CRE_lr_err[:,0],EIS_CRE_lr_err[:,1],color='darkblue',linestyle='dashed',alpha=0.05)
#    ax[1,0].plot(lag,Tadv_CRE_lr_lag_gm,'brown',label='CRE by Tadv',linestyle='dotted')
#    ax[1,0].fill_between(lag,Tadv_CRE_lr_err[:,0],Tadv_CRE_lr_err[:,1],color='brown',linestyle='dashed',alpha=0.05)
    
    ax[1,1].plot(lag,clr_sky_lag_gm,'green',label='CLR SKY')
#     ax[1,1].fill_between(lag,clr_sky_err[:,0],clr_sky_err[:,1],color='green',linestyle='dashed',alpha=0.05)
#     ax[1,1].plot(lag,dR_by_dT_gm,'crimson',label='$dR/dT$',linestyle='dashed')
#     ax[1,1].fill_between(lag,dR_by_dT_err[:,0],dR_by_dT_err[:,1],color='crimson',linestyle='dashed',alpha=0.05)
#     ax[1,1].plot(lag,dR_by_dq_sw_gm,'darkblue',label='$dR/dq_{SW}$',linestyle='dashdot')
#     ax[1,1].fill_between(lag,dR_by_dq_sw_err[:,0],dR_by_dq_sw_err[:,1],color='darkblue',linestyle='dashed',alpha=0.05)
#     ax[1,1].plot(lag,dR_by_dq_lw_gm,'orange',label='$dR/dq_{LW}$',linestyle='dotted')
#     ax[1,1].fill_between(lag,dR_by_dq_lw_err[:,0],dR_by_dq_lw_err[:,1],color='orange',linestyle='dashed',alpha=0.05)
    
    # Give plots their titles
    for i in np.arange(0,2,1):
        for j in np.arange(0,2,1):
            ax[i,j].set_title('Lagged Regression of Global-mean Radiation', size=20)
            ax[i,j].set_xlabel('Lag (months)',size=20)
            ax[i,j].set_ylabel('$W/m^2/K$',size=20)
            
            ax[i,j].axhline(y=0.0, color='k', linestyle='dotted')
            ax[i,j].axvline(x=0.0, color='k', linestyle='dotted')
            ax[i,j].axvline(x=-9.0, color='g', linestyle='dashed')
            ax[i,j].set_xlim([-12,12])
            ax[i,j].set_ylim([-.3,.3])
            ax[i,j].set_xticks(np.arange(-12,13,3))
            ax[i,j].tick_params(axis='x',labelsize=15)
            ax[i,j].tick_params(axis='y',labelsize=15)
            ax[i,j].legend()
            
            path = '/data/keeling/a/tjhanke2/enso-energy-budget/Output/Plots/linear_regression/'
            extent = ax[i,j].get_window_extent().transformed(fig.dpi_scale_trans.inverted())
            fig.savefig(path+'global_mean_regression_'+lin_title[i][j], bbox_inches=extent.expanded(1.2, 1.2))
            
    fig, ax = plt.subplots(2, 2, figsize=(18,12))
    fig.tight_layout(w_pad=6,h_pad=6)
    
    title1 = [['SST','EIS'],
              ['Tadv','none']]
    
    # Plot Trends
    ax[0,0].plot(lag,SST_anom_gm,'red',label='SST',linestyle='dashed')
    #ax[0,0].fill_between(lag,SST_err[:,0],SST_err[:,1],color='red',linestyle='dashed',alpha=0.05)
    ax[0,0].plot(lag,SST_CRE_gm,'black',label='CRE by SST')
    #ax[0,0].fill_between(lag,SST_CRE_lr_err[:,0],SST_CRE_lr_err[:,1],color='black',linestyle='dashed',alpha=0.05)
    
    ax[0,1].plot(lag,EIS_anom_gm,'blue',label='EIS',linestyle='dashed')
    #ax[0,1].fill_between(lag,EIS_err[:,0],EIS_err[:,1],color='blue',linestyle='dashed',alpha=0.05)
    ax[0,1].plot(lag,EIS_CRE_gm,'purple',label='CRE by EIS')
    #ax[0,1].fill_between(lag,EIS_CRE_lr_err[:,0],EIS_CRE_lr_err[:,1],color='purple',linestyle='dashed',alpha=0.05)
    
    ax[1,0].plot(lag,Tadv_anom_gm,'g',label='Tadv',linestyle='dashed')
    #ax[1,0].fill_between(lag,Tadv_err[:,0],Tadv_err[:,1],color='g',linestyle='dashed',alpha=0.05)
    ax[1,0].plot(lag,Tadv_CRE_gm,'orange',label='CRE by Tadv')
    #ax[1,0].fill_between(lag,Tadv_CRE_lr_err[:,0],Tadv_CRE_lr_err[:,1],color='orange',linestyle='dashed',alpha=0.05)
    
    ax[1,1].set_visible(False)
    
    for i in range(0,2):
        for j in range(0,2):
            ax[i,j].set_title('Global-mean ' + title1[i][j] + ' and CRE contribution regressed onto NINO3.4', fontsize=10)
            ax[i,j].set_xlabel('Lag (months)', fontsize=10)
            if j == 0:
                ax[i,j].set_ylabel('Regression Slope')
            else:
                ax[i,j].set_ylabel('').set_visible(False)
                
            ax[i,j].axhline(y=0.0, color='k', linestyle='dotted')
            ax[i,j].axvline(x=0.0, color='k', linestyle='dotted')
            ax[i,j].set_xlim([lag[0],lag[-1]])
            ax[i,j].set_ylim([-0.4,0.4])
            ax[i,j].tick_params(labelsize=10)
            ax[i,j].legend(prop={'size':10})
    
    path = '/data/keeling/a/tjhanke2/enso-energy-budget/Output/Plots/linear_regression/'
    fig.savefig(path + 'glob_mean_lagged_regress_ccfs.png', bbox_inches='tight')

# %%
def get_gm_lr_plot_2():
        # Set up subplots figure with PlateCarree projection
    fig, ax = plt.subplots(1, 1, figsize=(18,12))
    fig.tight_layout(w_pad=6,h_pad=6)
    
    vmin = -1
    vmax = 1

    # Plot Trends
    ax.plot(lag,net_cre_gm,'black',label='NET CRE')
    ax.fill_between(lag,net_cre_err[:,0],net_cre_err[:,1],color='black',linestyle='dashed',alpha=0.05)
    
    ax.plot(lag,loCld_cre_gm,'red',label='LOW CLD (> 680 hPa) CRE')
    ax.fill_between(lag,loCld_cre_err[:,0],loCld_cre_err[:,1],color='red',linestyle='dashed',alpha=0.05)
    
    ax.plot(lag,highCld_cre_gm,'blue',label='HIGH CLD (< 680 hPa) CRE')
    ax.fill_between(lag,highCld_cre_err[:,0],highCld_cre_err[:,1],color='blue',linestyle='dashed',alpha=0.05)
    
    ax.plot(lag,clr_sky_gm,'g',label='CLR SKY')
    ax.fill_between(lag,clr_sky_err[:,0],clr_sky_err[:,1],color='g',linestyle='dashed',alpha=0.05)
    
    ax.plot(lag,all_sky_gm,'purple',label='ALL SKY')
    ax.fill_between(lag,all_sky_err[:,0],all_sky_err[:,1],color='purple',linestyle='dashed',alpha=0.05)
    
    ax.set_title('Global-mean Radiation Anomalies Regressed onto Nino3.4', fontsize=20)
    ax.set_xlabel('Lag (months)', fontsize=20)
    ax.set_ylabel('Regression Slope', fontsize=20)

    ax.axhline(y=0.0, color='k', linestyle='dotted')
    ax.axvline(x=0.0, color='k', linestyle='dotted')
    ax.set_xlim([lag[0],lag[-1]])
    ax.set_ylim([-0.4,0.4])
    ax.tick_params(labelsize=20)
    ax.legend(prop={'size':20})
    
    path = '/data/keeling/a/tjhanke2/enso-energy-budget/Output/Plots/linear_regression/'
    fig.savefig(path + 'glob_mean_lagged_regress.png', bbox_inches='tight')
